# %% [markdown]
# # MAP REDUCE USING PYSPARK

# %% [markdown]
# Dataset: NYC 311 CALL CENTER INQUIRY DATA
#
# Big Data Framework: Spark using Pyspark
#
# Link to access the data: https://data.cityofnewyork.us/City-Government/311-Call-Center-Inquiry/wewp-mm3p/about_data

# %% [markdown]
# # INSTALL PYSPARK

# %%
# !pip install pyspark
# !pip install findspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Requirement already satisfied: findspark in /usr/local/lib/python3.10/dist-packages (2.0.1)

# %% [markdown]
# # IMPORT LIBRARIES

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import input_file_name
import glob
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql.functions import col
import findspark
findspark.init()
import pandas as pd
import matplotlib.pyplot as plt
import pylab as pl
from pyspark.sql.functions import year,month
from pyspark.sql.types import DateType
import pyspark.sql.functions as F
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark.sql.functions import split, col, concat_ws

# %% [markdown]
# # INITIALISE SPARK SESSION

# %%
# Initialize a Spark session
spark = SparkSession.builder.appName("ReadAllFiles").config('config_option','value').getOrCreate()

# %%
df=spark.read.csv('311_Call_Center_Inquiry.csv',header=True)

# %%
df.show()
# Out:
# +---------+----------+-----------+--------------------+--------+--------------------+--------------------+--------------------+--------------------+
# |UNIQUE_ID|      DATE|       TIME|           DATE_TIME|  AGENCY|         AGENCY_NAME|        INQUIRY_NAME|   BRIEF_DESCRIPTION|     CALL_RESOLUTION|
# +---------+----------+-----------+--------------------+--------+--------------------+--------------------+--------------------+--------------------+
# | 79381835|11/07/2011|10:03:18 AM|11/07/2011 10:03:...|     DOB|Department of Bui...|Schedule a Plan E...|Request an appoin...|      Scheduled Appt|
# | 79381836|11/07/2011| 3:51:49 PM|11/07/2011 03:51:...|   DOHMH|Department of Hea...|NYC Well - Drug a...|Information and t...|Transfer to City ...|
# | 79381837|11/07/2011|10:01:11 AM|11/07/2011 10:01:...|   3-1-1|   3-1-1 Call Center|Inmate Location a...|Get information o...|   Internal Transfer|
# | 79381838|11/07/2011| 6:31:44 PM|11/07/2011 06:31:...|TREASURY|Department of the...|Federal Tax Assis...|Federal tax forms...|Transfer to City ...|
# | 79381839|11/07/2011| 8:08:27 PM|11/07/2011 08:08:...|     TLC|Taxi and Limousin...|Lost Property in ...|Information for a...|Information Provided|
# | 79381840|11/07/2011|12:38:00 PM|11/07/2011 12:38:...|    DSNY|Department of San...|Special Waste Dis...|Instructions abou...|Information Provided|
# | 79381841|11/07/2011| 5:34:33 PM|11/07/2011 05:34:...|    CCRB|Civilian Complain...|Police Officer Mi...|Report unnecessar...|Transfer to City ...|
# | 79381842|11/07/2011|11:39:12 AM|11/07/2011 11:39:...|   DOHMH|Department of Hea...|Death Certificate...|Request for a cer...|  Routed to Web Page|
# | 79381843|11/07/2011| 5:14:59 PM|11/07/2011 05:14:...|   3-1-1|   3-1-1 Call Center|Service Request S...|Status of most Se...|Information Provided|
# | 79381844|11/07/2011| 9:51:01 AM|11/07/2011 09:51:...|     ACS|Administration fo...|Child Care Financ...|Assistance with s...|Transfer to City ...|
# | 79381845|11/07/2011| 9:28:22 AM|11/07/2011 09:28:...|     DOF|Department of Fin...|Find a Towed Vehi...|For Marshal or Sh...|   Internal Transfer|
# | 79381846|11/07/2011| 9:18:06 AM|11/07/2011 09:18:...|   DOHMH|Department of Hea...|Food Protection C...|Information about...|Transfer to City ...|
# | 79381847|11/07/2011| 3:42:11 PM|11/07/2011 03:42:...|   STATE|U.S. Department o...|Passport Information|Information about...|Information Provided|
# | 79381845|2011-07-11| 9:28:22 AM|11/07/2011 09:28:...|     DOF|Department of Fin...|Find a Towed Vehi...|For Marshal or Sh...|   Internal Transfer|2011|    7|
# | 79381846|2011-07-11| 9:18:06 AM|11/07/2011 09:18:...|   DOHMH|Department of Hea...|Food Protection C...|Information about...|Transfer to City ...|2011|    7|
# | 79381847|2011-07-11| 3:42:11 PM|11/07/2011 03:42:...|   STATE|U.S. Department o...|Passport Information|Information about...|Information Provided|2011|    7|
# | 79381849|2011-07-11| 9:00:59 PM|11/07/2011 09:00:...|   DOHMH|Department of Hea...|Rodent Complaint ...|Complaints about ...|             CSMS SR|2011|    7|
# | 79381850|2011-07-11|11:29:21 AM|11/07/2011 11:29:...|     HRA|Human Resources A...|Child Care Financ...|Child care paymen...|Information Provided|2011|    7|
# | 79381851|2011-07-11| 2:23:29 PM|11/07/2011 02:23:...|     DOE|Department of Edu...|   Division Transfer|Hidden service fo...|Transfer to City ...|2011|    7|
# | 79381852|2011-07-11| 3:41:33 PM|11/07/2011 03:41:...|     BOE|  Board of Elections|    Find a Poll Site|Find a polling si...|  Routed to Web Page|2011|    7|
# | 79381853|2011-07-11| 4:55:48 PM|11/07/2011 04:55:...|   DOHMH|Department of Hea...|Health Effects of...|Health informatio...|Transfer to City ...|2011|    7|
# | 79381854|2011-07-11|11:31:58 AM|11/07/2011 11:31:...|   DOHMH|Department of Hea...|Smoking Law Infor...|Request for the s...|Information Provided|2011|    7|
# | 79381855|2011-07-11|11:40:06 AM|11/07/2011 11:40:...|     BOE|  Board of Elections|Check Voter Regis...|Request to check ...|Transfer to City ...|2011|    7|
# +---------+----------+-----------+--------------------+--------+--------------------+--------------------+--------------------+--------------------+----+-----+
# only showing top 20 rows

# %%
df.count()
# Out:
# 92767867

# %% [markdown]
# # MAP REDUCE

# %%
# Select columns from the DataFrame
Inquiry_Agency=df.select("AGENCY")
Inquiry_Name=df.select("Inquiry_NAME")
Inquiry_Resolution=df.select("CALL_RESOLUTION")

# %%
#convert dataframe to RDD and perform Map Reduce
mapreduce_Agency=Inquiry_Agency.rdd.map(lambda x:(x,1))\
                                   .reduceByKey(lambda x,y:x+y)
mapreduce_Inquiry_Name=Inquiry_Name.rdd.map(lambda x:(x,1))\
                                   .reduceByKey(lambda x,y:x+y)

mapreduce_Resolution=Inquiry_Resolution.rdd.map(lambda x:(x,1))\
                                   .reduceByKey(lambda x,y:x+y)

# %%
#collect mapreduce_agency outcome to check Map Reduce output
mapreduce_Agency.collect()
# Out:
# [(Row(AGENCY='DHS'), 983079),
#  (Row(AGENCY='DOI'), 35759),
#  (Row(AGENCY='CHALL'), 135083),
#  (Row(AGENCY='CCPC'), 36),
#  (Row(AGENCY='ZTSTAGY'), 7),
#  (Row(AGENCY='IA'), 67361),
#  (Row(AGENCY='CWI'), 739),
#  (Row(AGENCY='OCHIA'), 9),
#  (Row(AGENCY='CQCAPD'), 3034),
#  (Row(AGENCY='CITIFIELD'), 2391),
#  (Row(AGENCY='NYSPARKS'), 1426),
#  (Row(AGENCY='TSASC'), 11),
#  (Row(AGENCY='ACS'), 758248),
#  (Row(AGENCY='MOIA'), 130407),
#  (Row(AGENCY='ABC'), 12921),
#  (Row(AGENCY='MAIG'), 5),
#  (Row(AGENCY='NYCOURTS'), 1194115),
#  (Row(AGENCY='DOITT'), 66641),
#  (Row(AGENCY='BPL'), 32714),
#  (Row(AGENCY='NYPD'), 8742374),
#  (Row(AGENCY='NYSDOH'), 317653),
#  (Row(AGENCY='OPA'), 18041),
#  (Row(AGENCY='REDCROSS'), 7436),
#  (Row(AGENCY='BSA'), 889),
#  (Row(AGENCY='GROWNYC'), 7683),
#  (Row(AGENCY='CEO'), 659),
#  (Row(AGENCY='BBB'), 61581),
#  (Row(AGENCY='BPBRX'), 228),
#  (Row(AGENCY='DSNY'), 5769668),
#  (Row(AGENCY='NYCRGB'), 42551),
#  (Row(AGENCY='MFANYC'), 18798),
#  (Row(AGENCY='USMARINE'), 3769),
#  (Row(AGENCY='NYSDCJS'), 3126),
#  (Row(AGENCY='HRA'), 3262602),
#  (Row(AGENCY='GRIEVANCECOMM'), 8756),
#  (Row(AGENCY='EDC'), 20735),
#  (Row(AGENCY='NYSED'), 59354),
#  (Row(AGENCY='CTYHL'), 1067),
#  (Row(AGENCY='NYSWORKERCOMPBD'), 16784),
#  (Row(AGENCY='NYW'), 50),
#  (Row(AGENCY='MOIGA'), 4),
#  (Row(AGENCY='VA'), 120),
#  (Row(AGENCY='NYSERDA'), 1668),
#  (Row(AGENCY='USARMY'), 120),
#  (Row(AGENCY='DOF'), 10091181),
#  (Row(AGENCY='VERIZON'), 80475),
#  (Row(AGENCY='USCOURTS'), 10260),
#  (Row(AGENCY='AJC'), 3),
#  (Row(AGENCY='NYSDFS'), 12023),
#  (Row(AGENCY='HPD'), 4866834),
#  (Row(AGENCY='NYSTAX'), 182295),
#  (Row(AGENCY='OPS'), 20489),
#  (Row(AGENCY='ACC'), 109469),
#  (Row(AGENCY='CFB'), 1982),
#  (Row(AGENCY='NYSBD'), 29373),
#  (Row(AGENCY='EPA'), 2637),
#  (Row(AGENCY='MOS'), 1123),
#  (Row(AGENCY='UNDC'), 1),
#  (Row(AGENCY='DEP'), 2635084),
#  (Row(AGENCY='HHC'), 411786),
#  (Row(AGENCY='VAC'), 24),
#  (Row(AGENCY='CUNY'), 67867),
#  (Row(AGENCY='NYCSC'), 2262),
#  (Row(AGENCY='DYCD'), 176130),
#  (Row(AGENCY='OZNY'), 136),
#  (Row(AGENCY='NYSCONSUMERPR'), 2089),
#  (Row(AGENCY='MOSE'), 1848),
#  (Row(AGENCY='CONED'), 280182),
#  (Row(AGENCY='NYSALCOHOLSUB'), 2923),
#  (Row(AGENCY='BPB'), 392),
#  (Row(AGENCY='MCU'), 24826),
#  (Row(AGENCY='DISCIPLINARYCOM'), 8112),
#  (Row(AGENCY='FISA'), 782),
#  (Row(AGENCY='TREASURY'), 216342),
#  (Row(AGENCY='NYIH'), 55738),
#  (Row(AGENCY='DEC'), 11614),
#  (Row(AGENCY='CJC'), 153290),
#  (Row(AGENCY='QPL'), 18569),
#  (Row(AGENCY='SCJC'), 4334),
#  (Row(AGENCY='FDIC'), 5072),
#  (Row(AGENCY=None), 17844593),
#  (Row(AGENCY='AAA'), 18),
#  (Row(AGENCY='DJJ'), 830),
#  (Row(AGENCY='AMTRAK'), 14978),
#  (Row(AGENCY='ECB'), 30018),
#  (Row(AGENCY='NYCEM'), 117710),
#  (Row(AGENCY='OTB'), 554),
#  (Row(AGENCY='NYSEMERGENCYMG'), 3007),
#  (Row(AGENCY='TLC'), 999459),
#  (Row(AGENCY='NYCCO'), 53378),
#  (Row(AGENCY='MOVA'), 18994),
#  (Row(AGENCY='OAG'), 81286),
#  (Row(AGENCY='CCRB'), 91745),
#  (Row(AGENCY='BAROFNYC'), 227049),
#  (Row(AGENCY='CPSC'), 835),
#  (Row(AGENCY='CENTRALPARKCONS'), 3094),
#  (Row(AGENCY='DOJ'), 89),
#  (Row(AGENCY='LOFT'), 995),
#  (Row(AGENCY='1DONOTUSE'), 7),
#  (Row(AGENCY='NYCHA'), 717221),
#  (Row(AGENCY='HHS'), 70047),
#  (Row(AGENCY='MOPD'), 139628),
#  (Row(AGENCY='DOHMH'), 3790040),
#  (Row(AGENCY='USCOMMERCE'), 21794),
#  (Row(AGENCY='DOP'), 11055),
#  (Row(AGENCY='BOC'), 5555),
#  (Row(AGENCY='BPQ'), 199),
#  (Row(AGENCY='TAX'), 38245),
#  (Row(AGENCY='BPCA'), 447),
#  (Row(AGENCY='OCFS'), 204217),
#  (Row(AGENCY='DDC'), 9232),
#  (Row(AGENCY='NYSDMV'), 839827),
#  (Row(AGENCY='COIB'), 869),
#  (Row(AGENCY='NYCSERVICE'), 37131),
#  (Row(AGENCY='LIPA'), 9156),
#  (Row(AGENCY='CCSC'), 31),
#  (Row(AGENCY='NYSDOS'), 118071),
#  (Row(AGENCY='OEC'), 68),
#  (Row(AGENCY='USDA'), 4238),
#  (Row(AGENCY='DOEMP'), 2),
#  (Row(AGENCY='RACING'), 798),
#  (Row(AGENCY='DOE'), 1705474),
#  (Row(AGENCY='OCB'), 2),
#  (Row(AGENCY='BOE'), 218075),
#  (Row(AGENCY='WF1'), 2),
#  (Row(AGENCY='NG'), 45870),
#  (Row(AGENCY='SSS'), 3434),
#  (Row(AGENCY='MOFTB'), 20978),
#  (Row(AGENCY='LMEC'), 46),
#  (Row(AGENCY='PANYNJ'), 134184),
#  (Row(AGENCY='LPC'), 5964),
#  (Row(AGENCY='USDHS'), 2648),
#  (Row(AGENCY='ENERGY'), 255),
#  (Row(AGENCY='USDOT'), 4036),
#  (Row(AGENCY='USDOL'), 6337),
#  (Row(AGENCY='GOVERNOR'), 7996),
#  (Row(AGENCY='HCR'), 177015),
#  (Row(AGENCY='FBI'), 1472),
#  (Row(AGENCY='MOAE'), 212),
#  (Row(AGENCY='DORIS'), 36506),
#  (Row(AGENCY='ENVIRONMENTCOM'), 7),
#  (Row(AGENCY='LMDC'), 6),
#  (Row(AGENCY='NPO'), 14303),
#  (Row(AGENCY='DOCS'), 103),
#  (Row(AGENCY='NYCERS'), 14202),
#  (Row(AGENCY='DCAS'), 298428),
#  (Row(AGENCY='NYPL'), 44135),
#  (Row(AGENCY='COMP'), 153796),
#  (Row(AGENCY='SCA'), 9304),
#  (Row(AGENCY='NYSINS'), 11930),
#  (Row(AGENCY='JEWELERVIGILANCE'), 727),
#  (Row(AGENCY='OAE'), 2),
#  (Row(AGENCY='NYSDOL'), 441351),
#  (Row(AGENCY='FMC'), 653),
#  (Row(AGENCY='SSA'), 322797),
#  (Row(AGENCY='NARA'), 695),
#  (Row(AGENCY='DESIGNCOM'), 336),
#  (Row(AGENCY='DOC'), 836514),
#  (Row(AGENCY='OATH'), 168993),
#  (Row(AGENCY='DV'), 16567),
#  (Row(AGENCY='CVB'), 1166),
#  (Row(AGENCY='HUD'), 8677),
#  (Row(AGENCY='NYCHH'), 68660),
#  (Row(AGENCY='OCME'), 17981),
#  (Row(AGENCY='BIC'), 19180),
#  (Row(AGENCY='KCPA'), 24),
#  (Row(AGENCY='DPR'), 1594718),
#  (Row(AGENCY='NYSBOPAROLE'), 16619),
#  (Row(AGENCY='BPM'), 146),
#  (Row(AGENCY='USCIS'), 6184),
#  (Row(AGENCY='FTC'), 63348),
#  (Row(AGENCY='SUNY'), 2796),
#  (Row(AGENCY='CCO'), 1),
#  (Row(AGENCY='CLERK'), 323548),
#  (Row(AGENCY='TFA'), 198),
#  (Row(AGENCY='NYSPSC'), 67753),
#  (Row(AGENCY='NYSDISABILITY'), 11582),
#  (Row(AGENCY='NPS'), 18568),
#  (Row(AGENCY='LAW'), 5467),
#  (Row(AGENCY='FDNY'), 371324),
#  (Row(AGENCY='CB'), 141876),
#  (Row(AGENCY='CAU'), 36670),
#  (Row(AGENCY='NYCPPF'), 24),
#  (Row(AGENCY='NYCBP'), 5),
#  (Row(AGENCY='MTA'), 1356797),
#  (Row(AGENCY='DCP'), 236856),
#  (Row(AGENCY='LMCCC'), 323),
#  (Row(AGENCY='USPERSONNELMGMT'), 5611),
#  (Row(AGENCY='MOSPCE'), 2358),
#  (Row(AGENCY='NJT'), 9959),
#  (Row(AGENCY='EEPC'), 14),
#  (Row(AGENCY='NYSJCPPSN'), 3553),
#  (Row(AGENCY='ASPCA'), 89967),
#  (Row(AGENCY='DOT'), 3315571),
#  (Row(AGENCY='OMB'), 486),
#  (Row(AGENCY='FCC'), 28458),
#  (Row(AGENCY='RIOC'), 1667),
#  (Row(AGENCY='OLR'), 16083),
#  (Row(AGENCY='FEMA'), 28223),
#  (Row(AGENCY='NYCOOA'), 8),
#  (Row(AGENCY='NYCPA'), 72407),
#  (Row(AGENCY='SBS'), 170359),
#  (Row(AGENCY='3-1-1'), 7595073),
#  (Row(AGENCY='OSC'), 11736),
#  (Row(AGENCY='USPS'), 215597),
#  (Row(AGENCY='NYCCOUN'), 2170),
#  (Row(AGENCY='CHARTER'), 54),
#  (Row(AGENCY='DCA'), 1192863),
#  (Row(AGENCY='OCECM'), 65683),
#  (Row(AGENCY='DCLA'), 45360),
#  (Row(AGENCY='CCHR'), 89724),
#  (Row(AGENCY='DOB'), 3087092),
#  (Row(AGENCY='STATE'), 115200),
#  (Row(AGENCY='COMMUTERLNK'), 674),
#  (Row(AGENCY='BPSI'), 496),
#  (Row(AGENCY='FAA'), 1541),
#  (Row(AGENCY='NYCDCOMM'), 139),
#  (Row(AGENCY='MOC'), 8646),
#  (Row(AGENCY='NYHISTSOC'), 140),
#  (Row(AGENCY='TAT'), 4),
#  (Row(AGENCY='NYSDOT'), 63674),
#  (Row(AGENCY='AGMKT'), 23439),
#  (Row(AGENCY='DVS'), 4565),
#  (Row(AGENCY='DFTA'), 639668)]

# %%
#convert mapReduce outcome to a dataframe
agency_output=mapreduce_Agency.toDF(["Agency",'Number'])
Resolution_output=mapreduce_Resolution.toDF(["Resolution",'Number'])
Inquiry_Name_output=mapreduce_Inquiry_Name.toDF(["Inquiry_Name",'Number'])

# %%
#convert the dataframe to Pandas
agency_output=agency_output.toPandas()
Resolution_output=Resolution_output.toPandas()
Inquiry_Name_output=Inquiry_Name_output.toPandas()

# %%
#Check Pandas output
agency_output
# Out:
#          Agency  Number
# 0        (DHS,)  983079
# 1        (DOI,)   35759
# 2      (CHALL,)  135083
# 3       (CCPC,)      36
# 4    (ZTSTAGY,)       7
# ..          ...     ...
# 219      (TAT,)       4
# 220   (NYSDOT,)   63674
# 221    (AGMKT,)   23439
# 222      (DVS,)    4565
# 223     (DFTA,)  639668
#
# [224 rows x 2 columns]

# %%
Inquiry_Name_output .head()
# Out:
#                                     Inquiry_Name  Number
# 0           (Rodent Complaint - Other Location,)  193594
# 1    (Gas Appliance or Pipe Permit - Manhattan,)     890
# 2              (Find a Community Board by Name,)   14153
# 3  (Job Training for Public Assistance Clients,)    3604
# 4        (Adult Probation Supervision - Queens,)    1624

# %% [markdown]
# # ENTIRE DATASET ANALYSIS

# %%
#Find the number of inquiries over the years
year_inquiries = df.groupBy('Year').count().orderBy('count', ascending=False)
year_inquiries = year_inquiries.toPandas()
year_inquiries = year_inquiries.sort_values('Year')

# %%
# Split the time column into hours and AM/PM
df = df.withColumn("time_parts", split(df["TIME"], " "))
# Extract the hour part (HH) and AM/PM part (AM/PM)
df = df.withColumn("hour", split(df["time_parts"][0], ":")[0])
df = df.withColumn("am_pm", df["time_parts"][1])
df = df.withColumn("hour_am_pm", concat_ws(" ", df["hour"], df["am_pm"]))
df.select("TIME", "hour_am_pm").show()
# Out:
# +-----------+----------+
# |       TIME|hour_am_pm|
# +-----------+----------+
# |10:03:18 AM|     10 AM|
# | 3:51:49 PM|      3 PM|
# |10:01:11 AM|     10 AM|
# | 6:31:44 PM|      6 PM|
# | 8:08:27 PM|      8 PM|
# |12:38:00 PM|     12 PM|
# | 5:34:33 PM|      5 PM|
# |11:39:12 AM|     11 AM|
# | 5:14:59 PM|      5 PM|
# | 9:51:01 AM|      9 AM|
# | 9:28:22 AM|      9 AM|
# | 9:18:06 AM|      9 AM|
# | 3:42:11 PM|      3 PM|
# | 9:00:59 PM|      9 PM|
# |11:29:21 AM|     11 AM|
# | 2:23:29 PM|      2 PM|
# | 3:41:33 PM|      3 PM|
# | 4:55:48 PM|      4 PM|
# |11:31:58 AM|     11 AM|
# |11:40:06 AM|     11 AM|
# +-----------+----------+
# only showing top 20 rows

# %%
# Group by the "hour_am_pm" column and count occurrences
grouped_df = df.groupBy("hour_am_pm").count()
time_inquiries =grouped_df.toPandas()
time_inquiries.head()
# Out:
#   hour_am_pm    count
# 0       6 PM  3664540
# 1       8 PM  2640865
# 2       7 AM  2108347
# 3       7 PM  3049605
# 4       6 AM   942193

# %% [markdown]
# # EXPORT CSV FILES FOR VISUALISATION ON POWER BI

# %%
path = 'drive/MyDrive/MIT805/Visual_data/'
agency_output.to_csv(path+"agency_output.csv", index=False)
year_inquiries.to_csv(path+"year_inquiries.csv", index=False)
Resolution_output.to_csv(path+"Resolution_output.csv", index=False)
Inquiry_Name_output.to_csv(path+"Inquiry_Name_output", index=False)
time_inquiries.to_csv(path+"Time_Inquiry.csv", index=False)
